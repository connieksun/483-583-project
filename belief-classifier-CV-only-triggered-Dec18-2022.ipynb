# %%
import torch
torch.cuda.empty_cache()

# %%
import sklearn
import pandas as pd
import numpy as np

# %%
import os
from os import listdir
import sys
import json

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
from transformers import AutoTokenizer
from datasets import Dataset, DatasetDict
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# %%
project_dir = "/xdisk/msurdeanu/alexeeva/data/annotations-related"

# %%
annotated_data = os.path.join(project_dir, "annotated_as_of_dec13_both_uganda_and_rice")
annotated_data
# Out:
# '/xdisk/msurdeanu/alexeeva/data/annotations-related/annotated_as_of_dec13_both_uganda_and_rice'

# %%
# df = pd.read_csv(os.path.join(annotated_data, "Subtask1-MainTask-double-annotation-prep-as-of-Nov2.tsv"), sep="\t")

# %%
# df.head()

# %%
# load annotated data
adf = pd.DataFrame()
for file in listdir(annotated_data):
    print(file)
    if file.endswith("tsv"):
        f_path = os.path.join(annotated_data, file)
        temp_df = pd.read_csv(f_path, sep='\t', usecols = ["paragraph", "mention text (just a few words around the trigger)","trigger","sentence","annotation: b (belief or attitude), n (not a belief and not an attitude)"]).dropna()
        print(len(temp_df))
        adf = pd.concat([adf, temp_df])
# Out:
# Subtask1-MainTask-double-annotation-prep-as-of-Nov2.tsv
# 1026

# %%
adf.head()
# Out:
#                                             sentence      trigger  \
# 0  Their willingness to use storage is , however ...  willingness
# 1  They appreciated the participatory approach , ...     consider
# 2  Based on this study , 30 m of Shuttle Radar To...   considered
# 3  Mechanical threshing was more popular in the D...      popular
# 4  The authors hope that the thriving features , ...         hope
#
#   mention text (just a few words around the trigger)  \
# 0  Their willingness to use storage is, however, ...
# 1                                      they consider
# 2  ) data was considered in our CFD simulation us...
# 3  was more popular in the Delta than in he Middl...
# 4  The authors hope that the thriving features, c...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  b
# 1                                                  b
# 2                                                  n
# 3                                                  b
# 4                                                  n
#
#                                            paragraph
# 0  Exhibit 14: Average Quantity of Maize, Rice an...
# 1  As part of our survey, most farmers recognize ...
# 2  In terms of simulation accuracy, the shapes of...
# 3  The Delta had less bird damage than the Middle...
# 4  This monograph describes the genetic resources...

# %%
adf["sentence"] = [s.strip() for s in adf["sentence"]]
adf = adf.drop_duplicates(subset = ["sentence", "mention text (just a few words around the trigger)"])

# %%
# len(df)

# %%
anns = adf["annotation: b (belief or attitude), n (not a belief and not an attitude)"]

# %%
list(anns).count("b")
# Out:
# 377

# %%
# percentage of sentences annotated as beliefs
386/1026
# Out:
# 0.3762183235867446

# %%
# annotated + sampled
df = adf
print("Annotated =", len(df))
# Out:
# Annotated = 1001

# %%
df['label'] = np.array([1 if x == "b" else 0 for x in df['annotation: b (belief or attitude), n (not a belief and not an attitude)']])

# %%
df.head()
# Out:
#                                             sentence      trigger  \
# 0  Their willingness to use storage is , however ...  willingness
# 1  They appreciated the participatory approach , ...     consider
# 2  Based on this study , 30 m of Shuttle Radar To...   considered
# 3  Mechanical threshing was more popular in the D...      popular
# 4  The authors hope that the thriving features , ...         hope
#
#   mention text (just a few words around the trigger)  \
# 0  Their willingness to use storage is, however, ...
# 1                                      they consider
# 2  ) data was considered in our CFD simulation us...
# 3  was more popular in the Delta than in he Middl...
# 4  The authors hope that the thriving features, c...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  b
# 1                                                  b
# 2                                                  n
# 3                                                  b
# 4                                                  n
#
#                                            paragraph  label
# 0  Exhibit 14: Average Quantity of Maize, Rice an...      1
# 1  As part of our survey, most farmers recognize ...      1
# 2  In terms of simulation accuracy, the shapes of...      0
# 3  The Delta had less bird damage than the Middle...      1
# 4  This monograph describes the genetic resources...      0

# %%
# from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# transformer_name = 'roberta-base'
transformer_name = "bert-base-cased"
# for cross validation, the model should be initialized inside the cv loop
# model = AutoModelForSequenceClassification.from_pretrained(transformer_name, num_labels=2)
tokenizer = AutoTokenizer.from_pretrained(transformer_name)

# %%
def tokenize(batch):
    return tokenizer(batch['sentence'], truncation=True)

# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics

def compute_metrics(eval_pred):
    y_true = eval_pred.label_ids
    y_pred = np.argmax(eval_pred.predictions, axis=-1)
    report = metrics.classification_report(y_true, y_pred)
    print("report: \n", report)
    
    print("rep type: ", type(report))
    

    return {'f1':metrics.f1_score(y_true, y_pred)}

# %%
from torch import nn
from transformers.modeling_outputs import SequenceClassifierOutput
from transformers.models.bert.modeling_bert import BertModel, BertPreTrainedModel

# https://github.com/huggingface/transformers/blob/65659a29cf5a079842e61a63d57fa24474288998/src/transformers/models/bert/modeling_bert.py#L1486

class BertForSequenceClassification(BertPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.bert = BertModel(config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, config.num_labels)
        self.init_weights()
        
    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, labels=None, **kwargs):
        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            **kwargs,
        )
        cls_outputs = outputs.last_hidden_state[:, 0, :]
        cls_outputs = self.dropout(cls_outputs)
        logits = self.classifier(cls_outputs)
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return SequenceClassifierOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions,
        )

# %%
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     compute_metrics=compute_metrics,
#     train_dataset=train_ds,
#     eval_dataset=eval_ds,
#     tokenizer=tokenizer,
#     )

# %%
from sklearn.model_selection import KFold

# %%
from transformers import AutoConfig

# %%
def get_sample_based_on_idx(data, indeces):
    return data.iloc[indeces, :].reset_index()

# %%
df.head(50)
# Out:
#                                              sentence        trigger  \
# 0   Their willingness to use storage is , however ...    willingness
# 1   They appreciated the participatory approach , ...       consider
# 2   Based on this study , 30 m of Shuttle Radar To...     considered
# 3   Mechanical threshing was more popular in the D...        popular
# 4   The authors hope that the thriving features , ...           hope
# 5   Of these , the EAC , COMESA , and SADC are all...     considered
# 6   Moreover , consumers already prefer local rice...         prefer
# 7   You need to be especially careful with items t...           want
# 8   Needless to say , it is the reflection of the ...            say
# 9   Government and political stability were long r...      perceived
# 10  Rice fields harbour a surprisingly rich level ...        thought
# 11  SRI should consequently not be thought of as a...        thought
# 12  They are considered in press : Comparative Stu...     considered
# 13  An additional 6 farmers are also expected to b...       expected
# 14  Note : Statistics are based on import data fro...       believed
# 15  As a result , the Poordi variety was the most ...    appreciated
# 16  Next , we regress the absolute differences ( d...    willingness
# 17  Farmers may not need insurance as rice grown i...      perceived
# 18  Respondent 's Number Date Location Translator ...          think
# 19  When IDPs and refugees returned to their farms...          found
# 20  Govermental Organizations that have interest i...    interest in
# 21  Provide identification information , test date...           want
# 22  Elissa Golberg , Assistant Deputy Minister , S...           said
# 23  d. Long Run Stock Options Incentive Plan : on ...     considered
# 24  A woman worker in Seychelles must give her emp...       expected
# 25  As such , they were pre-disposed to value farm...          value
# 26  She suggested that standardization and transpa...      confident
# 27  Approvals from spouses to own a business or le...     considered
# 28  The business case for renewables was strong , ...       expected
# 29  Rebuilding West Africa 's food potential408 Ho...           want
# 30  While we do not observe any systematic differe...           said
# 31  If your company wants to maintain this kind of...          wants
# 32  Because the maximum storage time is two years ...      preferred
# 33  Parents described an interest in participating...           felt
# 34  Crystal ( 2004 ) found that the world is facin...          found
# 35  This study contributes by presenting and compa...      perceived
# 36  As a result , women were better partners for g...           want
# 37  Considering all of these facts , the company a...        believe
# 38  Farmers will often prefer to grow two crops on...         prefer
# 39  32Told by a reporter in March 1996 that “ the ...         wanted
# 40  Preliminary research conducted by WARDA sugges...     appreciate
# 41  While there are good reasons to believe that g...        believe
# 42  If true , one would then expect that leaders b...         expect
# 43  Direct measures of empowerment generally focus...         values
# 44  Yield measured on samples overestimated the yi...  overestimated
# 45  7.6.5 Implementation considerations In additio...     considered
# 46  In time , as the 1998 law is implemented , the...       expected
# 47  Gomis and McCoy ( 2005 ) , for example , found...          found
# 48  She concluded by saying that developing countr...         saying
# 49  Even if those of seven farmers who put equal i...         regard
#
#    mention text (just a few words around the trigger)  \
# 0   Their willingness to use storage is, however, ...
# 1                                       they consider
# 2   ) data was considered in our CFD simulation us...
# 3   was more popular in the Delta than in he Middl...
# 4   The authors hope that the thriving features, c...
# 5   SADC are all considered significant regional i...
# 6   , consumers already prefer local rice in that ...
# 7        don’t want to inadvertently violate the EAR.
# 8   Needless to say, it is the reflection of the c...
# 9       is no longer perceived as a major constraint.
# 10  of biodiversity, thought to be amongst the gre...
# 11  consequently not be thought of as a pre-packag...
# 12  They are considered in press: Comparative Stud...
# 13  farmers are also expected to begin participati...
# 14       countries and are believed to be overstated.
# 15                        appreciated by the families
# 16  the collective willingness to pay for product ...
# 17  yields and was perceived to have lower risks t...
# 18  1 Do you think that rice production in the Riv...
# 19                                         many found
# 20                Organizations that have interest in
# 21  score recipients you want updated reports sent...
# 22  Global Affairs Canada said that inclusive trad...
# 23  leaders who are considered to be instrumental ...
# 24     notice before her expected date of childbirth.
# 25                    they were pre-disposed to value
# 26                     they would feel more confident
# 27  the home are considered procedures if required...
# 28  , and was expected to improve further in the c...
# 29  to what consumers want to buy; and (ii) transa...
# 30        to account for said imbalances at baseline.
# 31  If your company wants to maintain this kind of...
# 32  keeping seeds and preferred to buy them at the...
# 33  school because they felt the programme would p...
# 34                               Crystal (2004) found
# 35  econometrically estimated and perceived bird d...
# 36  in if they want to have a measurable impact on...
# 37  external counsels strongly believe that the ch...
# 38  Farmers will often prefer to grow two crops on...
# 39  the markets” wanted to know whether he was goi...
# 40                               consumers appreciate
# 41  good reasons to believe that general equilibri...
# 42  one would then expect that leaders benefit mor...
# 43                                         she values
# 44  measured on samples overestimated the yield of...
# 45  , to be considered as relevant to the local co...
# 46  sub-prefect levels are expected to play a grea...
# 47                   McCoy (2005), for example, found
# 48  She concluded by saying that developing countr...
# 49                                     farmers regard
#
#    annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                   b
# 1                                                   b
# 2                                                   n
# 3                                                   b
# 4                                                   n
# 5                                                   n
# 6                                                   b
# 7                                                   n
# 8                                                   n
# 9                                                   b
# 10                                                  b
# 11                                                  n
# 12                                                  n
# 13                                                  n
# 14                                                  b
# 15                                                  b
# 16                                                  n
# 17                                                  b
# 18                                                  n
# 19                                                  n
# 20                                                  b
# 21                                                  n
# 22                                                  n
# 23                                                  b
# 24                                                  n
# 25                                                  b
# 26                                                  n
# 27                                                  n
# 28                                                  n
# 29                                                  n
# 30                                                  n
# 31                                                  n
# 32                                                  b
# 33                                                  b
# 34                                                  n
# 35                                                  n
# 36                                                  n
# 37                                                  b
# 38                                                  b
# 39                                                  n
# 40                                                  b
# 41                                                  n
# 42                                                  n
# 43                                                  n
# 44                                                  n
# 45                                                  n
# 46                                                  b
# 47                                                  n
# 48                                                  n
# 49                                                  b
#
#                                             paragraph  label
# 0   Exhibit 14: Average Quantity of Maize, Rice an...      1
# 1   As part of our survey, most farmers recognize ...      1
# 2   In terms of simulation accuracy, the shapes of...      0
# 3   The Delta had less bird damage than the Middle...      1
# 4   This monograph describes the genetic resources...      0
# 5   Of these, the EAC, COMESA, and SADC are all co...      0
# 6   Since the introduction of improved rice variet...      1
# 7   Suppliers, consultants, and other third-partie...      0
# 8   After PAPRIZ started its activity, it became c...      0
# 9   New actions are possible to address the multip...      1
# 10  Rice fields harbour a surprisingly rich level ...      1
# 11  The System of Rice Intensification has gained ...      0
# 12  The following are abstracts of papers presente...      0
# 13  Farmers and extens ion agents v i s i t ing ou...      0
# 14  Note: Statistics are based on import data from...      1
# 15  When focusing on recession sorghum growing in ...      1
# 16  Next, we regress the absolute differences (dis...      0
# 17  However, when farmers are facing production ri...      1
# 18  Respondent's Number Date Location Translator I...      0
# 19  During the armed conflict of 2002–2007, many f...      0
# 20  Govermental Organizations that have interest i...      1
# 21  Service (see inside front cover) or write to: ...      0
# 22  Elissa Golberg, Assistant Deputy Minister, Str...      0
# 23  No stock options were granted to members of th...      1
# 24  Maternity leave Maternity and paternity at wor...      0
# 25  The intensive, participatory approach detailed...      1
# 26  Wanjiku Kimamo, Director, Sustainability and I...      0
# 27  Procedures A procedure is defined as any inter...      0
# 28  It was noted that the world was undergoing a t...      0
# 29  Rebuilding West Africa's food potential408 How...      0
# 30  There are two potential threats to the interna...      0
# 31  One disadvantage of using an EMC is that you m...      0
# 32  When focusing on recession sorghum growing in ...      1
# 33  relevant and responsive to the implementation ...      1
# 34  Crystal (2004) found that the world is facing ...      0
# 35  Granivorous birds, mainly the Red-billed Quele...      0
# 36  Sergi Corbalán, Fair Trade Advocacy Office str...      0
# 37  Certain holders of warrants issued by Ambev in...      1
# 38  At the scheme level, the first two sowing peri...      1
# 39  In June, Manuel introduced a comprehensive gro...      0
# 40  Improved industry competitiveness will require...      1
# 41  To express the gender gap in agricultural prod...      0
# 42  The apparent bias in favor of richer members w...      0
# 43  Direct measures of empowerment generally focus...      0
# 44  In the 1999 and 2000WS, farmers ordered 3 tonn...      0
# 45  Supervision should be supportive, striking the...      0
# 46  Although the basic idea behind the adoption of...      1
# 47  Positive Aspects of Rise of English Language U...      0
# 48  Ms. Naidu said that digital inclusion had prov...      0
# 49  The position of rice as staple food is not so ...      1

# %%
len(df)
# Out:
# 1001

# %%
set(df["label"])
# Out:
# {0, 1}

# %%
df["text"] = df["sentence"]

# %%
df.head()
# Out:
#                                             sentence      trigger  \
# 0  Their willingness to use storage is , however ...  willingness
# 1  They appreciated the participatory approach , ...     consider
# 2  Based on this study , 30 m of Shuttle Radar To...   considered
# 3  Mechanical threshing was more popular in the D...      popular
# 4  The authors hope that the thriving features , ...         hope
#
#   mention text (just a few words around the trigger)  \
# 0  Their willingness to use storage is, however, ...
# 1                                      they consider
# 2  ) data was considered in our CFD simulation us...
# 3  was more popular in the Delta than in he Middl...
# 4  The authors hope that the thriving features, c...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  b
# 1                                                  b
# 2                                                  n
# 3                                                  b
# 4                                                  n
#
#                                            paragraph  label  \
# 0  Exhibit 14: Average Quantity of Maize, Rice an...      1
# 1  As part of our survey, most farmers recognize ...      1
# 2  In terms of simulation accuracy, the shapes of...      0
# 3  The Delta had less bird damage than the Middle...      1
# 4  This monograph describes the genetic resources...      0
#
#                                                 text
# 0  Their willingness to use storage is , however ...
# 1  They appreciated the participatory approach , ...
# 2  Based on this study , 30 m of Shuttle Radar To...
# 3  Mechanical threshing was more popular in the D...
# 4  The authors hope that the thriving features , ...

# %%
num_epochs = 20
batch_size = 8
weight_decay = 0.01
# model_name = f'{transformer_name}-sequence-classification'
training_args = TrainingArguments(
#     output_dir="./results",
#     log_level='error',
#     num_train_epochs=num_epochs,
#     per_device_train_batch_size=batch_size,
#     per_device_eval_batch_size=batch_size,
#     evaluation_strategy='epoch',
#     weight_decay=weight_decay,
#     save_total_limit = 1,
#       # report_to = "none",
#   #     logging_steps = 'epoch',
#     #     load_best_model_at_end=True,
#     metric_for_best_model="eval_f1",
#     load_best_model_at_end=True,
#     save_strategy = "epoch"
    output_dir="./results",
    log_level='error',
    num_train_epochs=num_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    evaluation_strategy='epoch',
    save_strategy='epoch',
    weight_decay=weight_decay,
    load_best_model_at_end=True,
    metric_for_best_model="eval_f1"
    )

# %%
fold = 0
kfold = KFold(n_splits=10, shuffle=True, random_state=1)
for train_df_idx, eval_df_idx in kfold.split(df):
    print("FOLD: ", fold)
    new_df = pd.DataFrame()
    
    train_df = get_sample_based_on_idx(df, train_df_idx)
    print("LEN DF: ", len(train_df))
#     train_df['label'] = [int(item) for item in train_df["annotation: b (belief or attitude), n (not a belief and not an attitude)"]]
    print("done train df")
    eval_df = get_sample_based_on_idx(df, eval_df_idx)
#     eval_df["label"] = [int(item) for item in eval_df['annotation: b (belief or attitude), n (not a belief and not an attitude)']]
    print("done eval df")
    print("LEN EVAL: ", len(eval_df))
    print(eval_df.head())
    ds = DatasetDict()
    ds['train'] = Dataset.from_pandas(train_df)
    ds['validation'] = Dataset.from_pandas(eval_df)
    train_ds = ds['train'].map(
        tokenize, batched=True,
        remove_columns=['index', 'sentence', 'trigger', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph'],
    )
    eval_ds = ds['validation'].map(
        tokenize,
        batched=True,
        remove_columns=['index', 'sentence', 'trigger', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph'],
    )
    print(ds["validation"])

    config = AutoConfig.from_pretrained(
        transformer_name,
        num_labels=2,
    )

#     model = AutoModelForSequenceClassification.from_pretrained(transformer_name, num_labels=2)
#     tokenizer = AutoTokenizer.from_pretrained(transformer_name)
    model = (
        BertForSequenceClassification
        .from_pretrained(transformer_name, config=config)
    )
    trainer = Trainer(
        model=model,
        args=training_args,
        compute_metrics=compute_metrics,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        tokenizer=tokenizer,
    )
    trainer.train()
    # after training, predict (will use best model?)
    preds = trainer.predict(eval_ds)
#     print(preds, "<<<")
    final_preds = [np.argmax(x) for x in preds.predictions]
#     print(final_preds, "<--")
#     print("labs: ", eval_df["label"])
    real_f1 = metrics.f1_score(final_preds, eval_df["label"])
    print("F-1: ", real_f1)
    count_f_n = 0
    count_f_p = 0
    for i, item in enumerate(final_preds):
        if not item == eval_ds["label"][i]:
            false_df = pd.DataFrame()
            false_df["sentence"] = [eval_df["sentence"][i]]
            false_df["real"] = [eval_df["label"][i]]
            false_df["predicted"] = [item]
            new_df = pd.concat([new_df, false_df])
#             print("NEW: \n", false_df.head())
            if item == 0:
                count_f_n += 1

            else:
                count_f_p += 1
#                 print(eval_ds["sentence"][i], " " , eval_ds["label"][i], " ", item, "\n")

    #     else:
    #         print(">>>", list(X_test)[i], " " , y_test_enc[i], " ", list(y_test)[i], " ", item, "\n")
    print(count_f_n)
    print(count_f_p)

    
#     print(new_df.head())
#     new_df.to_csv(os.path.join("/xdisk/msurdeanu/alexeeva/data/annotations-related/false-pos-neg", "false_annotations_" + str(fold) + ".tsv"), sep="\t")  
    fold += 1
# Out:
# FOLD:  0
# LEN DF:  900
# done train df
# done eval df
# LEN EVAL:  101
#    index                                           sentence    trigger  \
# 0      6  Moreover , consumers already prefer local rice...     prefer
# 1     17  Farmers may not need insurance as rice grown i...  perceived
# 2     34  Crystal ( 2004 ) found that the world is facin...      found
# 3     35  This study contributes by presenting and compa...  perceived
# 4     41  While there are good reasons to believe that g...    believe
#
#   mention text (just a few words around the trigger)  \
# 0  , consumers already prefer local rice in that ...
# 1  yields and was perceived to have lower risks t...
# 2                               Crystal (2004) found
# 3  econometrically estimated and perceived bird d...
# 4  good reasons to believe that general equilibri...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  b
# 1                                                  b
# 2                                                  n
# 3                                                  n
# 4                                                  n
#
#                                            paragraph  label  \
# 0  Since the introduction of improved rice variet...      1
# 1  However, when farmers are facing production ri...      1
# 2  Crystal (2004) found that the world is facing ...      0
# 3  Granivorous birds, mainly the Red-billed Quele...      0
# 4  To express the gender gap in agricultural prod...      0
#
#                                                 text
# 0  Moreover , consumers already prefer local rice...
# 1  Farmers may not need insurance as rice grown i...
# 2  Crystal ( 2004 ) found that the world is facin...
# 3  This study contributes by presenting and compa...
# 4  While there are good reasons to believe that g...
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['index', 'sentence', 'trigger', 'mention text (just a few words around the trigger)', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph', 'label', 'text'],
#     num_rows: 101
# })
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/u3/alexeeva/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2260' max='2260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2260/2260 05:12, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.571428</td>
#       <td>0.617647</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.677112</td>
#       <td>0.586207</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.881812</td>
#       <td>0.596491</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.173479</td>
#       <td>0.712329</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.305000</td>
#       <td>1.357123</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.305000</td>
#       <td>1.268511</td>
#       <td>0.656250</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.305000</td>
#       <td>1.469745</td>
#       <td>0.702703</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.305000</td>
#       <td>1.592169</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.029400</td>
#       <td>1.427627</td>
#       <td>0.695652</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.029400</td>
#       <td>1.645962</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.029400</td>
#       <td>1.778604</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.029400</td>
#       <td>1.753907</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.029400</td>
#       <td>1.816105</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.015700</td>
#       <td>1.669939</td>
#       <td>0.626866</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.015700</td>
#       <td>1.802727</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.015700</td>
#       <td>1.833823</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.015700</td>
#       <td>1.855392</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.013900</td>
#       <td>1.860573</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.013900</td>
#       <td>1.871931</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.013900</td>
#       <td>1.875949</td>
#       <td>0.646154</td>
#     </tr>
#   </tbody>
# </table><p>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81        68
#            1       0.60      0.64      0.62        33
#
#     accuracy                           0.74       101
#    macro avg       0.71      0.72      0.71       101
# weighted avg       0.75      0.74      0.74       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        68
#            1       0.68      0.52      0.59        33
#
#     accuracy                           0.76       101
#    macro avg       0.73      0.70      0.71       101
# weighted avg       0.75      0.76      0.75       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        68
#            1       0.71      0.52      0.60        33
#
#     accuracy                           0.77       101
#    macro avg       0.75      0.71      0.72       101
# weighted avg       0.76      0.77      0.76       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84        68
#            1       0.65      0.79      0.71        33
#
#     accuracy                           0.79       101
#    macro avg       0.77      0.79      0.77       101
# weighted avg       0.81      0.79      0.80       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        68
#            1       0.64      0.70      0.67        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.75      0.75       101
# weighted avg       0.78      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84        68
#            1       0.68      0.64      0.66        33
#
#     accuracy                           0.78       101
#    macro avg       0.75      0.74      0.75       101
# weighted avg       0.78      0.78      0.78       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83        68
#            1       0.63      0.79      0.70        33
#
#     accuracy                           0.78       101
#    macro avg       0.76      0.78      0.77       101
# weighted avg       0.80      0.78      0.79       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        68
#            1       0.67      0.73      0.70        33
#
#     accuracy                           0.79       101
#    macro avg       0.76      0.78      0.77       101
# weighted avg       0.80      0.79      0.79       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83        68
#            1       0.65      0.61      0.62        33
#
#     accuracy                           0.76       101
#    macro avg       0.73      0.72      0.73       101
# weighted avg       0.76      0.76      0.76       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83        68
#            1       0.65      0.61      0.62        33
#
#     accuracy                           0.76       101
#    macro avg       0.73      0.72      0.73       101
# weighted avg       0.76      0.76      0.76       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83        68
#            1       0.65      0.61      0.62        33
#
#     accuracy                           0.76       101
#    macro avg       0.73      0.72      0.73       101
# weighted avg       0.76      0.76      0.76       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81        68
#            1       0.62      0.64      0.63        33
#
#     accuracy                           0.75       101
#    macro avg       0.72      0.72      0.72       101
# weighted avg       0.75      0.75      0.75       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        68
#            1       0.66      0.64      0.65        33
#
#     accuracy                           0.77       101
#    macro avg       0.74      0.74      0.74       101
# weighted avg       0.77      0.77      0.77       101
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84        68
#            1       0.65      0.79      0.71        33
#
#     accuracy                           0.79       101
#    macro avg       0.77      0.79      0.77       101
# weighted avg       0.81      0.79      0.80       101
#
# rep type:  <class 'str'>
# F-1:  0.7123287671232875
# 7
# 14
# FOLD:  1
# LEN DF:  901
# done train df
# done eval df
# LEN EVAL:  100
#    index                                           sentence     trigger  \
# 0      2  Based on this study , 30 m of Shuttle Radar To...  considered
# 1      3  Mechanical threshing was more popular in the D...     popular
# 2      8  Needless to say , it is the reflection of the ...         say
# 3     13  An additional 6 farmers are also expected to b...    expected
# 4     50  The farmers trust the front-line government sp...       trust
#
#   mention text (just a few words around the trigger)  \
# 0  ) data was considered in our CFD simulation us...
# 1  was more popular in the Delta than in he Middl...
# 2  Needless to say, it is the reflection of the c...
# 3  farmers are also expected to begin participati...
# 4  The farmers trust the front-line government sp...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  n
# 1                                                  b
# 2                                                  n
# 3                                                  n
# 4                                                  b
#
#                                            paragraph  label  \
# 0  In terms of simulation accuracy, the shapes of...      0
# 1  The Delta had less bird damage than the Middle...      1
# 2  After PAPRIZ started its activity, it became c...      0
# 3  Farmers and extens ion agents v i s i t ing ou...      0
# 4  Government agencies, and the institutions they...      1
#
#                                                 text
# 0  Based on this study , 30 m of Shuttle Radar To...
# 1  Mechanical threshing was more popular in the D...
# 2  Needless to say , it is the reflection of the ...
# 3  An additional 6 farmers are also expected to b...
# 4  The farmers trust the front-line government sp...
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['index', 'sentence', 'trigger', 'mention text (just a few words around the trigger)', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph', 'label', 'text'],
#     num_rows: 100
# })
# /home/u3/alexeeva/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2260' max='2260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2260/2260 05:12, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.644154</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.001799</td>
#       <td>0.684932</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.267970</td>
#       <td>0.727273</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.616623</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.270100</td>
#       <td>1.543015</td>
#       <td>0.702703</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.270100</td>
#       <td>1.140814</td>
#       <td>0.731707</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.270100</td>
#       <td>1.809203</td>
#       <td>0.704545</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.270100</td>
#       <td>1.788921</td>
#       <td>0.743590</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.036900</td>
#       <td>1.901645</td>
#       <td>0.717949</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.036900</td>
#       <td>2.041246</td>
#       <td>0.691358</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.036900</td>
#       <td>2.052499</td>
#       <td>0.691358</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.036900</td>
#       <td>2.125882</td>
#       <td>0.691358</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.036900</td>
#       <td>2.201565</td>
#       <td>0.691358</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.014100</td>
#       <td>2.181889</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.014100</td>
#       <td>2.211006</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.014100</td>
#       <td>2.207296</td>
#       <td>0.683544</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.014100</td>
#       <td>2.232386</td>
#       <td>0.683544</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.011500</td>
#       <td>2.224102</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.011500</td>
#       <td>2.238045</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.011500</td>
#       <td>2.240728</td>
#       <td>0.700000</td>
#     </tr>
#   </tbody>
# </table><p>
# report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.98      0.81        59
#            1       0.93      0.34      0.50        41
#
#     accuracy                           0.72       100
#    macro avg       0.81      0.66      0.65       100
# weighted avg       0.79      0.72      0.68       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82        59
#            1       0.78      0.61      0.68        41
#
#     accuracy                           0.77       100
#    macro avg       0.77      0.75      0.75       100
# weighted avg       0.77      0.77      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        59
#            1       0.78      0.68      0.73        41
#
#     accuracy                           0.79       100
#    macro avg       0.79      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79        59
#            1       0.70      0.73      0.71        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.76      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        59
#            1       0.79      0.63      0.70        41
#
#     accuracy                           0.78       100
#    macro avg       0.78      0.76      0.76       100
# weighted avg       0.78      0.78      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        59
#            1       0.73      0.73      0.73        41
#
#     accuracy                           0.78       100
#    macro avg       0.77      0.77      0.77       100
# weighted avg       0.78      0.78      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77        59
#            1       0.66      0.76      0.70        41
#
#     accuracy                           0.74       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.74      0.74       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84        59
#            1       0.78      0.71      0.74        41
#
#     accuracy                           0.80       100
#    macro avg       0.80      0.79      0.79       100
# weighted avg       0.80      0.80      0.80       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82        59
#            1       0.76      0.68      0.72        41
#
#     accuracy                           0.78       100
#    macro avg       0.78      0.77      0.77       100
# weighted avg       0.78      0.78      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        59
#            1       0.70      0.68      0.69        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        59
#            1       0.70      0.68      0.69        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        59
#            1       0.70      0.68      0.69        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        59
#            1       0.70      0.68      0.69        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        59
#            1       0.72      0.68      0.70        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        59
#            1       0.72      0.68      0.70        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79        59
#            1       0.71      0.66      0.68        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79        59
#            1       0.71      0.66      0.68        41
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.75      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        59
#            1       0.72      0.68      0.70        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        59
#            1       0.72      0.68      0.70        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        59
#            1       0.72      0.68      0.70        41
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84        59
#            1       0.78      0.71      0.74        41
#
#     accuracy                           0.80       100
#    macro avg       0.80      0.79      0.79       100
# weighted avg       0.80      0.80      0.80       100
#
# rep type:  <class 'str'>
# F-1:  0.7435897435897435
# 12
# 8
# FOLD:  2
# LEN DF:  901
# done train df
# done eval df
# LEN EVAL:  100
#    index                                           sentence      trigger  \
# 0     12  They are considered in press : Comparative Stu...   considered
# 1     16  Next , we regress the absolute differences ( d...  willingness
# 2     19  When IDPs and refugees returned to their farms...        found
# 3     23  d. Long Run Stock Options Incentive Plan : on ...   considered
# 4     47  Gomis and McCoy ( 2005 ) , for example , found...        found
#
#   mention text (just a few words around the trigger)  \
# 0  They are considered in press: Comparative Stud...
# 1  the collective willingness to pay for product ...
# 2                                         many found
# 3  leaders who are considered to be instrumental ...
# 4                   McCoy (2005), for example, found
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  n
# 1                                                  n
# 2                                                  n
# 3                                                  b
# 4                                                  n
#
#                                            paragraph  label  \
# 0  The following are abstracts of papers presente...      0
# 1  Next, we regress the absolute differences (dis...      0
# 2  During the armed conflict of 2002–2007, many f...      0
# 3  No stock options were granted to members of th...      1
# 4  Positive Aspects of Rise of English Language U...      0
#
#                                                 text
# 0  They are considered in press : Comparative Stu...
# 1  Next , we regress the absolute differences ( d...
# 2  When IDPs and refugees returned to their farms...
# 3  d. Long Run Stock Options Incentive Plan : on ...
# 4  Gomis and McCoy ( 2005 ) , for example , found...
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['index', 'sentence', 'trigger', 'mention text (just a few words around the trigger)', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph', 'label', 'text'],
#     num_rows: 100
# })
# /home/u3/alexeeva/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2260' max='2260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2260/2260 05:03, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.567833</td>
#       <td>0.423077</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.604085</td>
#       <td>0.705882</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.858895</td>
#       <td>0.720930</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.007233</td>
#       <td>0.692308</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.334900</td>
#       <td>1.495419</td>
#       <td>0.641026</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.334900</td>
#       <td>1.458370</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.334900</td>
#       <td>1.572162</td>
#       <td>0.710526</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.334900</td>
#       <td>2.253654</td>
#       <td>0.608696</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.045800</td>
#       <td>1.657921</td>
#       <td>0.693333</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.045800</td>
#       <td>1.770324</td>
#       <td>0.647887</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.045800</td>
#       <td>1.800748</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.045800</td>
#       <td>1.783301</td>
#       <td>0.693333</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.045800</td>
#       <td>1.846364</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.018400</td>
#       <td>1.850413</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.018400</td>
#       <td>1.862329</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.018400</td>
#       <td>1.878870</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.018400</td>
#       <td>1.901152</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.013600</td>
#       <td>1.922993</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.013600</td>
#       <td>1.929011</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.013600</td>
#       <td>1.931562</td>
#       <td>0.675676</td>
#     </tr>
#   </tbody>
# </table><p>
# report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.97      0.80        61
#            1       0.85      0.28      0.42        39
#
#     accuracy                           0.70       100
#    macro avg       0.76      0.62      0.61       100
# weighted avg       0.74      0.70      0.65       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78        61
#            1       0.65      0.77      0.71        39
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.75      0.74       100
# weighted avg       0.76      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79        61
#            1       0.66      0.79      0.72        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.77      0.76       100
# weighted avg       0.78      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        61
#            1       0.69      0.69      0.69        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        61
#            1       0.64      0.64      0.64        39
#
#     accuracy                           0.72       100
#    macro avg       0.71      0.71      0.71       100
# weighted avg       0.72      0.72      0.72       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85        61
#            1       0.81      0.64      0.71        39
#
#     accuracy                           0.80       100
#    macro avg       0.80      0.77      0.78       100
# weighted avg       0.80      0.80      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82        61
#            1       0.73      0.69      0.71        39
#
#     accuracy                           0.78       100
#    macro avg       0.77      0.76      0.77       100
# weighted avg       0.78      0.78      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        61
#            1       0.70      0.54      0.61        39
#
#     accuracy                           0.73       100
#    macro avg       0.72      0.70      0.70       100
# weighted avg       0.73      0.73      0.72       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        61
#            1       0.72      0.67      0.69        39
#
#     accuracy                           0.77       100
#    macro avg       0.76      0.75      0.75       100
# weighted avg       0.77      0.77      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.85      0.81        61
#            1       0.72      0.59      0.65        39
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.72      0.73       100
# weighted avg       0.75      0.75      0.74       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        61
#            1       0.72      0.67      0.69        39
#
#     accuracy                           0.77       100
#    macro avg       0.76      0.75      0.75       100
# weighted avg       0.77      0.77      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        61
#            1       0.71      0.64      0.68        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.74      0.74       100
# weighted avg       0.76      0.76      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79        61
#            1       0.66      0.79      0.72        39
#
#     accuracy                           0.76       100
#    macro avg       0.75      0.77      0.76       100
# weighted avg       0.78      0.76      0.76       100
#
# rep type:  <class 'str'>
# F-1:  0.7209302325581396
# 8
# 16
# FOLD:  3
# LEN DF:  901
# done train df
# done eval df
# LEN EVAL:  100
#    index                                           sentence      trigger  \
# 0      0  Their willingness to use storage is , however ...  willingness
# 1     14  Note : Statistics are based on import data fro...     believed
# 2     40  Preliminary research conducted by WARDA sugges...   appreciate
# 3     46  In time , as the 1998 law is implemented , the...     expected
# 4     57  All farmers already preferred to use fertilize...    preferred
#
#   mention text (just a few words around the trigger)  \
# 0  Their willingness to use storage is, however, ...
# 1       countries and are believed to be overstated.
# 2                               consumers appreciate
# 3  sub-prefect levels are expected to play a grea...
# 4  All farmers already preferred to use fertilize...
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  b
# 1                                                  b
# 2                                                  b
# 3                                                  b
# 4                                                  b
#
#                                            paragraph  label  \
# 0  Exhibit 14: Average Quantity of Maize, Rice an...      1
# 1  Note: Statistics are based on import data from...      1
# 2  Improved industry competitiveness will require...      1
# 3  Although the basic idea behind the adoption of...      1
# 4  Prior to the intervention of PCE and its donor...      1
#
#                                                 text
# 0  Their willingness to use storage is , however ...
# 1  Note : Statistics are based on import data fro...
# 2  Preliminary research conducted by WARDA sugges...
# 3  In time , as the 1998 law is implemented , the...
# 4  All farmers already preferred to use fertilize...
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['index', 'sentence', 'trigger', 'mention text (just a few words around the trigger)', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph', 'label', 'text'],
#     num_rows: 100
# })
# /home/u3/alexeeva/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2260' max='2260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2260/2260 04:57, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.601725</td>
#       <td>0.542373</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.811868</td>
#       <td>0.440000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.708159</td>
#       <td>0.712329</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.136772</td>
#       <td>0.698795</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.328800</td>
#       <td>1.443211</td>
#       <td>0.675325</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.328800</td>
#       <td>1.722877</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.328800</td>
#       <td>1.451835</td>
#       <td>0.701299</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.328800</td>
#       <td>1.695451</td>
#       <td>0.686567</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.050000</td>
#       <td>1.544532</td>
#       <td>0.696970</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.050000</td>
#       <td>2.311984</td>
#       <td>0.681818</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.050000</td>
#       <td>2.040792</td>
#       <td>0.657143</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.050000</td>
#       <td>2.217453</td>
#       <td>0.658228</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.050000</td>
#       <td>2.159407</td>
#       <td>0.675325</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.025500</td>
#       <td>2.148532</td>
#       <td>0.675325</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.025500</td>
#       <td>2.122581</td>
#       <td>0.693333</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.025500</td>
#       <td>2.146814</td>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.025500</td>
#       <td>2.168481</td>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.015900</td>
#       <td>2.179913</td>
#       <td>0.675325</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.015900</td>
#       <td>2.132829</td>
#       <td>0.693333</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.015900</td>
#       <td>2.084098</td>
#       <td>0.693333</td>
#     </tr>
#   </tbody>
# </table><p>
# report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81        64
#            1       0.70      0.44      0.54        36
#
#     accuracy                           0.73       100
#    macro avg       0.72      0.67      0.68       100
# weighted avg       0.72      0.73      0.71       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.95      0.81        64
#            1       0.79      0.31      0.44        36
#
#     accuracy                           0.72       100
#    macro avg       0.75      0.63      0.63       100
# weighted avg       0.74      0.72      0.68       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        64
#            1       0.70      0.72      0.71        36
#
#     accuracy                           0.79       100
#    macro avg       0.77      0.78      0.77       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79        64
#            1       0.62      0.81      0.70        36
#
#     accuracy                           0.75       100
#    macro avg       0.74      0.76      0.74       100
# weighted avg       0.78      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        64
#            1       0.63      0.72      0.68        36
#
#     accuracy                           0.75       100
#    macro avg       0.73      0.74      0.74       100
# weighted avg       0.76      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        64
#            1       0.64      0.69      0.67        36
#
#     accuracy                           0.75       100
#    macro avg       0.73      0.74      0.73       100
# weighted avg       0.76      0.75      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81        64
#            1       0.66      0.75      0.70        36
#
#     accuracy                           0.77       100
#    macro avg       0.75      0.77      0.76       100
# weighted avg       0.78      0.77      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        64
#            1       0.74      0.64      0.69        36
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.76      0.76       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
# ...
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.78      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83        60
#            1       0.74      0.72      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.78      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83        60
#            1       0.74      0.72      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.78      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        60
#            1       0.76      0.70      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        60
#            1       0.76      0.70      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        60
#            1       0.76      0.70      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        60
#            1       0.76      0.70      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        60
#            1       0.76      0.70      0.73        40
#
#     accuracy                           0.79       100
#    macro avg       0.78      0.77      0.78       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        60
#            1       0.80      0.70      0.75        40
#
#     accuracy                           0.81       100
#    macro avg       0.81      0.79      0.80       100
# weighted avg       0.81      0.81      0.81       100
#
# rep type:  <class 'str'>
# F-1:  0.7466666666666666
# 12
# 7
# FOLD:  9
# LEN DF:  901
# done train df
# done eval df
# LEN EVAL:  100
#    index                                           sentence      trigger  \
# 0      7  You need to be especially careful with items t...         want
# 1     15  As a result , the Poordi variety was the most ...  appreciated
# 2     22  Elissa Golberg , Assistant Deputy Minister , S...         said
# 3     25  As such , they were pre-disposed to value farm...        value
# 4     26  She suggested that standardization and transpa...    confident
#
#   mention text (just a few words around the trigger)  \
# 0       don’t want to inadvertently violate the EAR.
# 1                        appreciated by the families
# 2  Global Affairs Canada said that inclusive trad...
# 3                    they were pre-disposed to value
# 4                     they would feel more confident
#
#   annotation: b (belief or attitude), n (not a belief and not an attitude)  \
# 0                                                  n
# 1                                                  b
# 2                                                  n
# 3                                                  b
# 4                                                  n
#
#                                            paragraph  label  \
# 0  Suppliers, consultants, and other third-partie...      0
# 1  When focusing on recession sorghum growing in ...      1
# 2  Elissa Golberg, Assistant Deputy Minister, Str...      0
# 3  The intensive, participatory approach detailed...      1
# 4  Wanjiku Kimamo, Director, Sustainability and I...      0
#
#                                                 text
# 0  You need to be especially careful with items t...
# 1  As a result , the Poordi variety was the most ...
# 2  Elissa Golberg , Assistant Deputy Minister , S...
# 3  As such , they were pre-disposed to value farm...
# 4  She suggested that standardization and transpa...
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['index', 'sentence', 'trigger', 'mention text (just a few words around the trigger)', 'annotation: b (belief or attitude), n (not a belief and not an attitude)', 'paragraph', 'label', 'text'],
#     num_rows: 100
# })
# /home/u3/alexeeva/.local/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2260' max='2260' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2260/2260 05:08, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.520840</td>
#       <td>0.439024</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.410993</td>
#       <td>0.655738</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.881910</td>
#       <td>0.655738</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.911643</td>
#       <td>0.746667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.309300</td>
#       <td>1.066156</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.309300</td>
#       <td>1.407700</td>
#       <td>0.647887</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.309300</td>
#       <td>1.757258</td>
#       <td>0.615385</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.309300</td>
#       <td>1.815687</td>
#       <td>0.642857</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.040900</td>
#       <td>1.920841</td>
#       <td>0.641026</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.040900</td>
#       <td>1.733687</td>
#       <td>0.646154</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.040900</td>
#       <td>1.743674</td>
#       <td>0.637681</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.040900</td>
#       <td>1.845962</td>
#       <td>0.628571</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.040900</td>
#       <td>1.901205</td>
#       <td>0.647059</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.017200</td>
#       <td>1.876121</td>
#       <td>0.647059</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.017200</td>
#       <td>1.923533</td>
#       <td>0.676471</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.017200</td>
#       <td>2.006829</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.017200</td>
#       <td>2.006893</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.014600</td>
#       <td>2.019124</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.014600</td>
#       <td>2.012249</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.014600</td>
#       <td>2.019037</td>
#       <td>0.666667</td>
#     </tr>
#   </tbody>
# </table><p>
# report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.99      0.86        69
#            1       0.90      0.29      0.44        31
#
#     accuracy                           0.77       100
#    macro avg       0.83      0.64      0.65       100
# weighted avg       0.80      0.77      0.73       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        69
#            1       0.67      0.65      0.66        31
#
#     accuracy                           0.79       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        69
#            1       0.67      0.65      0.66        31
#
#     accuracy                           0.79       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.79      0.79      0.79       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85        69
#            1       0.64      0.90      0.75        31
#
#     accuracy                           0.81       100
#    macro avg       0.79      0.84      0.80       100
# weighted avg       0.85      0.81      0.82       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81        69
#            1       0.59      0.77      0.67        31
#
#     accuracy                           0.76       100
#    macro avg       0.73      0.76      0.74       100
# weighted avg       0.79      0.76      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.75      0.81        69
#            1       0.57      0.74      0.65        31
#
#     accuracy                           0.75       100
#    macro avg       0.72      0.75      0.73       100
# weighted avg       0.78      0.75      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.67      0.75        69
#            1       0.51      0.77      0.62        31
#
#     accuracy                           0.70       100
#    macro avg       0.69      0.72      0.68       100
# weighted avg       0.76      0.70      0.71       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74        69
#            1       0.51      0.87      0.64        31
#
#     accuracy                           0.70       100
#    macro avg       0.71      0.75      0.69       100
# weighted avg       0.79      0.70      0.71       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77        69
#            1       0.53      0.81      0.64        31
#
#     accuracy                           0.72       100
#    macro avg       0.71      0.74      0.71       100
# weighted avg       0.78      0.72      0.73       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        69
#            1       0.62      0.68      0.65        31
#
#     accuracy                           0.77       100
#    macro avg       0.73      0.74      0.74       100
# weighted avg       0.78      0.77      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        69
#            1       0.58      0.71      0.64        31
#
#     accuracy                           0.75       100
#    macro avg       0.72      0.74      0.72       100
# weighted avg       0.77      0.75      0.76       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.75      0.80        69
#            1       0.56      0.71      0.63        31
#
#     accuracy                           0.74       100
#    macro avg       0.71      0.73      0.71       100
# weighted avg       0.76      0.74      0.75       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        69
#            1       0.59      0.71      0.65        31
#
#     accuracy                           0.76       100
#    macro avg       0.73      0.75      0.73       100
# weighted avg       0.78      0.76      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        69
#            1       0.59      0.71      0.65        31
#
#     accuracy                           0.76       100
#    macro avg       0.73      0.75      0.73       100
# weighted avg       0.78      0.76      0.77       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83        69
#            1       0.62      0.74      0.68        31
#
#     accuracy                           0.78       100
#    macro avg       0.75      0.77      0.75       100
# weighted avg       0.80      0.78      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        69
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.77       100
#    macro avg       0.74      0.76      0.75       100
# weighted avg       0.79      0.77      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        69
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.77       100
#    macro avg       0.74      0.76      0.75       100
# weighted avg       0.79      0.77      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        69
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.77       100
#    macro avg       0.74      0.76      0.75       100
# weighted avg       0.79      0.77      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        69
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.77       100
#    macro avg       0.74      0.76      0.75       100
# weighted avg       0.79      0.77      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82        69
#            1       0.61      0.74      0.67        31
#
#     accuracy                           0.77       100
#    macro avg       0.74      0.76      0.75       100
# weighted avg       0.79      0.77      0.78       100
#
# rep type:  <class 'str'>
# report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85        69
#            1       0.64      0.90      0.75        31
#
#     accuracy                           0.81       100
#    macro avg       0.79      0.84      0.80       100
# weighted avg       0.85      0.81      0.82       100
#
# rep type:  <class 'str'>
# F-1:  0.7466666666666666
# 3
# 16

# %%
# print(train_df["label"])

# %%
# torch.cuda.memory_summary(device=None, abbreviated=False)
