# %%
from datasets import load_dataset, load_from_disk

from setfit import SetFitModel, SetFitTrainer

import torch
import numpy as np
import pandas as pd
# set to True to use the gpu (if there is one available)
use_gpu = True

# select device
if torch.cuda.is_available():
    device = torch.cuda.current_device()
else:
    device =  -1
print(device)
# Out:
# 0

# %%
dataset = load_from_disk("data/belief_dataset/")

data_dict = dataset.train_test_split(test_size=0.95)
train_ds = data_dict['train']

for entry in train_ds:
    print(entry['label'])
# Out:
# 2
# 2
# 0
# 0
# 0
# 2
# 0
# 1
# 2
# 0
# 2
# 0
# 2
# 2
# 0
# 3
# 0
# 2

# %%
test_ds = data_dict['test']

from sentence_transformers.losses import CosineSimilarityLoss

model = SetFitModel.from_pretrained("sentence-transformers/all-mpnet-base-v2")
trainer = SetFitTrainer(
    model=model,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    loss_class=CosineSimilarityLoss,
    batch_size=4,
    num_iterations=20, # Number of text pairs to generate for contrastive learning
    num_epochs=1 # Number of epochs to use for contrastive learning
)
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
# Train and evaluate!
trainer.train()
metrics = trainer.evaluate()
# Out:
# ***** Running training *****
#   Num examples = 720
#   Num epochs = 1
#   Total optimization steps = 180
#   Total train batch size = 4
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/180 [00:00<?, ?it/s]
# ***** Running evaluation *****

# %%
trainer.model._save_pretrained(save_directory="models/few-shot-mpnet-base-v2")

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="models/few-shot-mpnet-base-v2/", device=device)
# Out:
# Some weights of the model checkpoint at models/few-shot-mpnet-base-v2/ were not used when initializing MPNetForSequenceClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MPNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at models/few-shot-mpnet-base-v2/ and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Failed to determine 'entailment' label id from the label2id mapping in the model config. Setting to -1. Define a descriptive label2id mapping in the model config to ensure correct outputs.

# %%
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

labels = ["neither", "negative", "positive", "both"]
pred_i_list = []
for pred in tqdm(classifier(KeyDataset(test_ds, "text"), batch_size=2, candidate_labels=labels)):
    pred_i = labels.index(pred["labels"][0])
    pred_i_list.append(pred_i)
# Out:
#   0%|          | 0/173 [00:00<?, ?it/s]
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 346 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 347 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 348 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 349 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 350 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 351 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 352 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 353 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 354 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 355 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 356 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 357 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 358 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 359 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 360 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 361 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 362 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 363 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 364 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 365 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 366 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 367 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 368 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 369 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 370 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 371 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 372 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 373 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 374 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 375 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 376 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 377 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 378 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 379 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 380 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 381 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 382 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 383 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 384 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 385 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 386 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 387 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 388 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 389 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 390 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 391 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 392 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 393 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 394 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 395 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 396 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 397 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 398 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 399 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 400 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 401 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 402 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 403 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 404 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 405 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 406 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 407 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 408 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 409 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 410 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 411 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 412 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 413 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 414 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 415 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 416 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 417 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 418 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 419 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 420 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 421 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 422 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 423 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 424 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 425 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 426 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 427 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 428 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 429 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 430 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 431 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 432 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 433 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 434 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 435 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 436 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 437 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 438 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 439 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 440 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 441 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 442 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 443 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 444 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 445 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 446 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 447 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 448 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 449 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 450 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 451 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 452 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 453 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 454 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 455 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 456 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 457 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 458 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 459 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 460 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 461 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 462 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 463 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 464 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 465 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 466 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 467 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 468 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 469 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 470 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 471 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 472 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 473 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 474 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 475 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 476 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 477 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 478 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 479 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 480 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 481 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 482 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 483 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 484 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 485 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 486 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 487 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 488 samples have been fetched.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 644 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 645 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 646 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 647 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 648 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 649 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 650 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 651 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 652 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 653 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 654 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 655 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 656 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 657 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 658 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 659 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 660 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 661 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 662 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 663 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 664 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 665 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 666 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 667 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 668 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 669 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 670 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 671 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 672 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 673 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 674 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 675 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 676 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 677 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 678 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 679 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 680 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 681 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 682 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 683 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 684 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 685 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 686 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 687 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 688 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 689 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\torch\utils\data\dataloader.py:529: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000002992FF57FD0> was reported to be 345 (when accessing len(dataloader)), but 690 samples have been fetched.
#   warnings.warn(warn_msg)

# %%
from sklearn.metrics import classification_report

y_true = test_ds["label"]
y_pred = pred_i_list
print(classification_report(y_true, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#      neither       0.00      0.00      0.00       114
#     negative       0.24      0.31      0.27        64
#     positive       0.40      0.76      0.53       139
#         both       0.00      0.00      0.00        28
#
#     accuracy                           0.37       345
#    macro avg       0.16      0.27      0.20       345
# weighted avg       0.21      0.37      0.26       345
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\conni\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
